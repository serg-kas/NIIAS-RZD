# %% [markdown]
# ### Настройка окружения

# %%
# !git clone 'https://github.com/serg-kas/NIIAS-RZD' '/home/jupyter/work/resources/NIIAS-RZD'
# Out:
# Cloning into '/home/jupyter/work/resources/NIIAS-RZD'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 7), reused 21 (delta 5), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
# !/usr/local/bin/python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 2.1 MB 1.8 MB/s
# ...
#   WARNING: The scripts pip, pip3, pip3.10 and pip3.8 are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 60.9 MB 71 kB/s
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
# %pip install albumentations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.7/116.7 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 MB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.6/195.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.3 MB/s eta 0:00:00
# ...
#   WARNING: The scripts lsm2bin, tiff2fsspec, tiffcomment and tifffile are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/home/jupyter/.local/bin' which is not on PATH.
# ...

# %%
# %pip install tensorflow -U

# %%
# %pip freeze > requirements.txt

# %% [markdown]
# ### Загрузка датасета

# %%
from cloud_ml.storage.api import Storage

# To retrieve application id and secret:
# 1. Go to link: https://oauth.yandex.ru/client/new
# 2. Choose 'Web services'
# 3. Paste into 'Callback URI': https://oauth.yandex.ru/verification_code
# 4. Set up permissions on yandex disk
disk = Storage.ya_disk(application_id='65ae613750f24f7382082c8ba4021c09', application_secret='a910bfc862104fa1b9c92abb7e9edcee')

# downloading contents of the remote directory into the local one
disk.get_dir('NIIAS-RZD-DATA', '/home/jupyter/work/resources')
# Out:
# Enter the confirmation code:  7614030
# Open the following url to obtain confirmation code: https://oauth.yandex.ru/authorize?response_type=code&client_id=65ae613750f24f7382082c8ba4021c09&display=popup&force_confirm=yes
# ...
# Done
# /kernel/lib/python3.8/site-packages/ml_kernel/kernel.py:864: UserWarning: The following variables cannot be serialized: disk
#   warnings.warn(message)

# %%
#!c1.8
# !unzip test_dataset_test.zip -d /home/jupyter/work/resources/test
# Out:
# Archive:  test_dataset_test.zip
#   inflating: /home/jupyter/work/resources/test/img_0.214619045608739.png
#   inflating: /home/jupyter/work/resources/test/img_0.222008559373284.png
#   inflating: /home/jupyter/work/resources/test/img_0.257733754655467.png
#   inflating: /home/jupyter/work/resources/test/img_0.277061116090067.png
#   inflating: /home/jupyter/work/resources/test/img_0.313319927799937.png
#   inflating: /home/jupyter/work/resources/test/img_0.336916118603806.png
#   inflating: /home/jupyter/work/resources/test/img_0.343310309785112.png
#   inflating: /home/jupyter/work/resources/test/img_0.352211267903936.png
#   inflating: /home/jupyter/work/resources/test/img_0.377769777183416.png
#   inflating: /home/jupyter/work/resources/test/img_0.409301175516405.png
#   inflating: /home/jupyter/work/resources/test/img_0.441372885373862.png
#   inflating: /home/jupyter/work/resources/test/img_0.445093357509564.png
# ...

# %%
# !ls /home/jupyter/work/resources/test -l | wc
# Out:
#    1001    9002   78310

# %%
#!c1.8
# !unzip train_dataset_train.zip
# Out:
# 048.png
#   inflating: train/images/img_0.8861359222489213.png
#   inflating: train/images/img_0.8863298720105849.png
#   inflating: train/images/img_0.8863531924739475.png
#   inflating: train/images/img_0.8864318566829327.png
#   inflating: train/images/img_0.8866162501168725.png
#   inflating: train/images/img_0.886664079584862.png
#   inflating: train/images/img_0.886705987525784.png
#   inflating: train/images/img_0.8867942016793003.png
#   inflating: train/images/img_0.8868581313534538.png
#   inflating: train/images/img_0.8869933622493129.png
#   inflating: train/images/img_0.8870172144198188.png
#   inflating: train/images/img_0.8872173549040304.png
#   inflating: train/images/img_0.8872739504156568.png
#   inflating: train/images/img_0.8873488454684606.png
#   inflating: train/images/img_0.8873883801228349.png
#   inflating: train/images/img_0.8874245364831622.png
#   inflating: train/images/img_0.8874662276520532.png
#   inflating: train/images/img_0.8875619597800353.png
# ...

# %%
# !ls /home/jupyter/work/resources/train/images -l | wc
# Out:
#    8204   73829  642078

# %%
# !ls /home/jupyter/work/resources/train/mask -l | wc
# Out:
#    8204   73829  617467
